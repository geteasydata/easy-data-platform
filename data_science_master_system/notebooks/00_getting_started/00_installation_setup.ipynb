# %% [markdown]
# # 🚀 Installation & Setup Guide
#
# **Author**: Data Science Master System
# **Difficulty**: ⭐ Beginner
# **Time**: 15 minutes
# **Prerequisites**: Python 3.9+ installed
#
# ## Learning Objectives
# - Set up the development environment
# - Install required packages
# - Verify installation
# - Understand project structure

# %% [markdown]
# ## 1. Environment Setup

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python path: {sys.executable}")
# Out:
# Python version: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# Python path: C:\Users\IBM\AppData\Local\Programs\Python\Python313\python.exe

# %%
# Install core packages
# !pip install numpy pandas scikit-learn matplotlib seaborn jupyter

# For deep learning (optional)
# !pip install torch torchvision transformers

# For the Data Science Master System
# !pip install -e ../..

# %% [markdown]
# ## 2. Verify Installation

# %%
# Core packages
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

print("✅ Core packages installed:")
print(f"  NumPy: {np.__version__}")
print(f"  Pandas: {pd.__version__}")
print(f"  Scikit-learn: {sklearn.__version__}")
# Out:
# ✅ Core packages installed:
#   NumPy: 2.3.3
#   Pandas: 2.3.3
#   Scikit-learn: 1.7.2

# %%
# Optional: Deep learning
try:
    import torch
    print(f"\n✅ PyTorch: {torch.__version__}")
   # print(f"  CUDA available: {torch.cuda.is_available()}")
except ImportError:
    print("⚠️ PyTorch not installed (optional)")

try:
    import transformers
    print(f"✅ Transformers: {transformers.__version__}")
except ImportError:
    print("⚠️ Transformers not installed (optional)")
# Out:
# ✅ PyTorch: 2.9.1+cpu
# ✅ Transformers: 4.57.3

# %% [markdown]
# ## 3. Project Structure

# %%
structure = """
data_science_master_system/
├── notebooks/
│   ├── 00_getting_started/   # You are here!
│   ├── 01_core_ml/           # Core machine learning
│   ├── 02_computer_vision/   # CV specialization
│   ├── 03_nlp_transformers/  # NLP specialization
│   ├── 04_time_series/       # Time series
│   ├── 05_advanced_topics/   # GNN, RL, etc.
│   └── 06_production/        # MLOps & deployment
├── data/                     # Sample datasets
├── src/                      # Source code
├── configs/                  # Configuration files
├── tests/                    # Test suite
└── docs/                     # Documentation
"""
print(structure)
# Out:
# data_science_master_system/
# ├── notebooks/
# │   ├── 00_getting_started/   # You are here!
# │   ├── 01_core_ml/           # Core machine learning
# │   ├── 02_computer_vision/   # CV specialization
# │   ├── 03_nlp_transformers/  # NLP specialization
# │   ├── 04_time_series/       # Time series
# │   ├── 05_advanced_topics/   # GNN, RL, etc.
# │   └── 06_production/        # MLOps & deployment
# ├── data/                     # Sample datasets
# ├── src/                      # Source code
# ├── configs/                  # Configuration files
# ├── tests/                    # Test suite
# └── docs/                     # Documentation

# %% [markdown]
# ## 4. Next Steps
#
# 1. **Beginner Track**: Continue to `01_quick_start_tutorial.ipynb`
# 2. **Generate Sample Data**: Run the data generator script
# 3. **Explore**: Browse notebooks by topic
#
# ---
# **Related Notebooks**: 01_quick_start_tutorial, 02_basic_data_analysis
# **Tags**: setup, installation, environment, beginner
